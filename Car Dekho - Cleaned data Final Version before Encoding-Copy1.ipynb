# %%
import pandas as pd

df_bangalore = pd.read_excel(r"C:\Users\Bhuvanesh\Desktop\Yogesh Guvi\Car Dekho\Dataset\bangalore_cars.xlsx")
df_chennai = pd.read_excel(r"C:\Users\Bhuvanesh\Desktop\Yogesh Guvi\Car Dekho\Dataset\chennai_cars.xlsx")
df_delhi = pd.read_excel(r"C:\Users\Bhuvanesh\Desktop\Yogesh Guvi\Car Dekho\Dataset\delhi_cars.xlsx")
df_hyderabad = pd.read_excel(r"C:\Users\Bhuvanesh\Desktop\Yogesh Guvi\Car Dekho\Dataset\hyderabad_cars.xlsx")
df_jaipur = pd.read_excel(r"C:\Users\Bhuvanesh\Desktop\Yogesh Guvi\Car Dekho\Dataset\jaipur_cars.xlsx")
df_kolkata = pd.read_excel(r"C:\Users\Bhuvanesh\Desktop\Yogesh Guvi\Car Dekho\Dataset\kolkata_cars.xlsx")
df_bangalore['City']="Bangalore"
df_chennai['City']="Chennai"
df_delhi['City']="Delhi"
df_hyderabad['City']="Hyderabad"
df_jaipur['City']="Jaipur"
df_kolkata['City']="Kolkata"

merged_df = pd.concat([df_bangalore,df_chennai,df_delhi,df_hyderabad,df_jaipur,df_kolkata], ignore_index=True)
merged_df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 8364  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8365  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8366  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 8367  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8368  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
import pandas as pd
import ast

# Extract 'new_car_detail' column from merged_df
df_new_car_detail = merged_df['new_car_detail']

# Flatten the 'new_car_detail' column by converting it from stringified lists/dictionaries to actual Python objects
df_new_car_detail_flattened = pd.DataFrame(df_new_car_detail.apply(ast.literal_eval).tolist())

# Step 1: Extract 'trendingText' from df_new_car_detail_flattened_1
df_trendingText = df_new_car_detail_flattened['trendingText']

# Step 2: Convert 'trendingText' column into a DataFrame (if needed)
df_new_car_detail_flattened_1 = pd.DataFrame(df_trendingText)

# Step 3: Drop 'trendingText' from the original flattened DataFrame
df_new_car_detail_flattened.drop("trendingText", axis=1, inplace=True)

# Display the final DataFrame after dropping 'trendingText'
print(df_new_car_detail_flattened)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %%
df_new_car_detail_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   it                8369 non-null   int64
#  1   ft                8369 non-null   object
#  2   bt                8369 non-null   object
#  3   km                8369 non-null   object
#  4   transmission      8369 non-null   object
#  5   ownerNo           8369 non-null   int64
#  6   owner             8369 non-null   object
#  7   oem               8369 non-null   object
#  8   model             8369 non-null   object
#  9   modelYear         8369 non-null   int64
#  10  centralVariantId  8369 non-null   int64
#  11  variantName       8369 non-null   object
#  12  price             8369 non-null   object
#  13  priceActual       8369 non-null   object
#  14  priceSaving       8369 non-null   object
#  15  priceFixedText    0 non-null      object
# ...

# %%
df_new_car_detail_flattened.drop(['priceActual','priceSaving','priceFixedText'],axis=1, inplace=True)
df_new_car_detail_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   it                8369 non-null   int64
#  1   ft                8369 non-null   object
#  2   bt                8369 non-null   object
#  3   km                8369 non-null   object
#  4   transmission      8369 non-null   object
#  5   ownerNo           8369 non-null   int64
#  6   owner             8369 non-null   object
#  7   oem               8369 non-null   object
#  8   model             8369 non-null   object
#  9   modelYear         8369 non-null   int64
#  10  centralVariantId  8369 non-null   int64
#  11  variantName       8369 non-null   object
#  12  price             8369 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 850.1+ KB

# %%
# Convert specific columns to 'category' type
df_new_car_detail_flattened['ft'] = df_new_car_detail_flattened['ft'].astype('category')
df_new_car_detail_flattened['bt'] = df_new_car_detail_flattened['bt'].astype('category')
df_new_car_detail_flattened['transmission'] = df_new_car_detail_flattened['transmission'].astype('category')
df_new_car_detail_flattened['owner'] = df_new_car_detail_flattened['owner'].astype('category')
df_new_car_detail_flattened['oem'] = df_new_car_detail_flattened['oem'].astype('category')
df_new_car_detail_flattened['model'] = df_new_car_detail_flattened['model'].astype('category')
df_new_car_detail_flattened['variantName'] = df_new_car_detail_flattened['variantName'].astype('category')

# Remove commas and convert 'km' column to integer, handle errors
df_new_car_detail_flattened['km'] = df_new_car_detail_flattened['km'].str.replace(',', '').astype(int)

# Check the final DataFrame information
print(df_new_car_detail_flattened.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   it                8369 non-null   int64
#  1   ft                8369 non-null   category
#  2   bt                8369 non-null   category
#  3   km                8369 non-null   int32
#  4   transmission      8369 non-null   category
#  5   ownerNo           8369 non-null   int64
#  6   owner             8369 non-null   category
#  7   oem               8369 non-null   category
#  8   model             8369 non-null   category
#  9   modelYear         8369 non-null   int64
#  10  centralVariantId  8369 non-null   int64
#  11  variantName       8369 non-null   category
#  12  price             8369 non-null   object
# dtypes: category(7), int32(1), int64(4), object(1)
# memory usage: 527.5+ KB
# None

# %%
df_new_car_detail_flattened
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  120000       Manual        3  3rd Owner
# 1      0  Petrol        SUV   32706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback   11949       Manual        1  1st Owner
# 3      0  Petrol      Sedan   17794       Manual        1  1st Owner
# 4      0  Diesel        SUV   60000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 8364   0  Petrol  Hatchback   10000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  120000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan   50000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback   40000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  120000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %%
df_new_car_detail_flattened['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8369 entries, 0 to 8368
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 8369 non-null   object
# dtypes: object(1)
# memory usage: 65.5+ KB

# %%
# Count the number of cells containing 'lakh'
count_lakh = df_new_car_detail_flattened['price'].str.contains('lakh', case=False, na=False).sum()

# Count the number of cells containing 'cr'
count_cr = df_new_car_detail_flattened['price'].str.contains('cr', case=False, na=False).sum()

# Display the counts
print(f"Number of 'lakh' cells: {count_lakh}")
print(f"Number of 'cr' cells: {count_cr}")
# Out:
# Number of 'lakh' cells: 8239
# Number of 'cr' cells: 20

# %%
# Filter rows where 'price' does not contain 'lakh' or 'cr'
filtered_df = df_new_car_detail_flattened[~df_new_car_detail_flattened['price'].str.contains('lakh|cr', case=False, na=False)]

# Display the filtered DataFrame
print(filtered_df)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner      oem  \
# 584    0  Petrol   Minivans   80000       Manual        5  5th Owner   Maruti
# 595    0  Petrol  Hatchback  120000       Manual        3  3rd Owner  Hyundai
# 675    0  Diesel  Hatchback   50000       Manual        1  1st Owner     Tata
# 690    0  Petrol      Sedan   50000       Manual        3  3rd Owner   Maruti
# 737    0  Petrol      Sedan   70000       Manual        1  1st Owner     Opel
# ...   ..     ...        ...     ...          ...      ...        ...      ...
# 8127   0  Petrol  Hatchback   60000       Manual        1  1st Owner   Maruti
# 8162   0  Petrol  Hatchback   30000       Manual        1  1st Owner   Maruti
# 8310   0  Petrol  Hatchback   50000       Manual        1  1st Owner   Maruti
# 8312   0  Petrol  Hatchback   20000       Manual        1  1st Owner   Maruti
# 8314   0  Petrol  Hatchback   40000       Manual        2  2nd Owner   Maruti
#
# ...

# %%
import numpy as np
import re

# Function to clean and convert 'lakh', 'cr', and 'ore' to numeric
def convert_price(value):
    # Remove any special characters (non-alphanumeric except for '.'), keep 'lakh', 'cr', and 'ore'
    value = re.sub(r'[^\d\.a-zA-Z\s]', '', value).lower().strip()  # Keep digits, '.', and 'lakh', 'cr', 'ore'
    
    # Handle 'lakh', 'cr', and 'ore'
    if 'lakh' in value:
        return float(value.replace('lakh', '').strip()) * 100000
    elif 'cr' in value or 'ore' in value:  # Treat 'ore' as 'cr'
        return float(value.replace('cr', '').replace('ore', '').strip()) * 10000000
    else:
        try:
            # For other numeric values, convert directly
            return float(value.replace(',', '').strip())
        except ValueError:
            # Return NaN for invalid entries
            return np.nan

# Apply the function to the 'price' column
df_new_car_detail_flattened['price_cleaned'] = df_new_car_detail_flattened['price'].apply(convert_price)

# Display the cleaned DataFrame
print(df_new_car_detail_flattened)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  120000       Manual        3  3rd Owner
# 1      0  Petrol        SUV   32706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback   11949       Manual        1  1st Owner
# 3      0  Petrol      Sedan   17794       Manual        1  1st Owner
# 4      0  Diesel        SUV   60000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 8364   0  Petrol  Hatchback   10000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  120000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan   50000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback   40000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  120000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %%
df_new_car_detail_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   it                8369 non-null   int64
#  1   ft                8369 non-null   category
#  2   bt                8369 non-null   category
#  3   km                8369 non-null   int32
#  4   transmission      8369 non-null   category
#  5   ownerNo           8369 non-null   int64
#  6   owner             8369 non-null   category
#  7   oem               8369 non-null   category
#  8   model             8369 non-null   category
#  9   modelYear         8369 non-null   int64
#  10  centralVariantId  8369 non-null   int64
#  11  variantName       8369 non-null   category
#  12  price             8369 non-null   object
#  13  price_cleaned     8369 non-null   float64
# dtypes: category(7), float64(1), int32(1), int64(4), object(1)
# memory usage: 592.9+ KB

# %%
df_new_car_overview=merged_df['new_car_overview']
df_new_car_overview
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 8364    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 8369, dtype: object

# %%
import pandas as pd
import ast

# Assuming df_new_car_overview is a Series containing strings of dictionaries
s = [ast.literal_eval(i) for i in df_new_car_overview]  # Use literal_eval for safety
df_new_car_overview_1 = pd.DataFrame(s)  # Create a DataFrame |from the list of dictionaries

# Extract the 'top' column and the 'heading'
df_new_car_overview_1_top = df_new_car_overview_1['top']
df_new_car_overview_1_heading = df_new_car_overview_1['heading'].iloc[0]  # Assuming the heading is the same for all rows

# Function to convert list of dictionaries to a single dictionary with key-value pairs including heading
def convert_to_dict(row):
    return {f"{df_new_car_overview_1_heading} - {item['key']}": item['value'] for item in row}

# Apply the function to each row in the Series
all_data = df_new_car_overview_1_top.apply(convert_to_dict)

# Convert the Series of dictionaries to a DataFrame
df_new_car_overview_flattened = pd.DataFrame(all_data.tolist())

# Display the first 5 rows of the final DataFrame
print(df_new_car_overview_flattened.head())
# Out:
#   Car overview - Registration Year Car overview - Insurance Validity  \
# 0                             2015             Third Party insurance
# 1                         Feb 2018                     Comprehensive
# 2                        Sept 2018                     Comprehensive
# 3                         Dec 2014                     Comprehensive
# 4                             2015             Third Party insurance
#
#   Car overview - Fuel Type Car overview - Seats Car overview - Kms Driven  \
# 0                   Petrol              5 Seats              1,20,000 Kms
# 1                   Petrol              5 Seats                32,706 Kms
# 2                   Petrol              5 Seats                11,949 Kms
# 3                   Petrol              5 Seats                17,794 Kms
# 4                   Diesel              5 Seats                60,000 Kms
#
#   Car overview - RTO Car overview - Ownership  \
# 0               KA51              Third Owner
# ...

# %%
df_new_car_overview_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Car overview - Registration Year    8317 non-null   object
#  1   Car overview - Insurance Validity   8365 non-null   object
#  2   Car overview - Fuel Type            8369 non-null   object
#  3   Car overview - Seats                8363 non-null   object
#  4   Car overview - Kms Driven           8367 non-null   object
#  5   Car overview - RTO                  7481 non-null   object
#  6   Car overview - Ownership            8337 non-null   object
#  7   Car overview - Engine Displacement  8365 non-null   object
#  8   Car overview - Transmission         8369 non-null   object
#  9   Car overview - Year of Manufacture  8349 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 654.0+ KB

# %%
df_new_car_overview_flattened.isnull().sum()
# Out:
# Car overview - Registration Year       52
# Car overview - Insurance Validity       4
# Car overview - Fuel Type                0
# Car overview - Seats                    6
# Car overview - Kms Driven               2
# Car overview - RTO                    888
# Car overview - Ownership               32
# Car overview - Engine Displacement      4
# Car overview - Transmission             0
# Car overview - Year of Manufacture     20
# dtype: int64

# %%
# Assuming 'Car overview - Year of Manufacture' is the column with the values you want to fill
df_new_car_overview_flattened['Car overview - Registration Year'] = df_new_car_overview_flattened['Car overview - Registration Year'].fillna(df_new_car_overview_flattened['Car overview - Year of Manufacture'])
df_new_car_overview_flattened['Car overview - Year of Manufacture'] = df_new_car_overview_flattened['Car overview - Year of Manufacture'].fillna(df_new_car_overview_flattened['Car overview - Registration Year'])

df_new_car_overview_flattened.isnull().sum()
# Out:
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\1608238310.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_new_car_overview_flattened['Car overview - Year of Manufacture'] = df_new_car_overview_flattened['Car overview - Year of Manufacture'].fillna(df_new_car_overview_flattened['Car overview - Registration Year'])
# Car overview - Registration Year       20
# Car overview - Insurance Validity       4
# Car overview - Fuel Type                0
# Car overview - Seats                    6
# Car overview - Kms Driven               2
# Car overview - RTO                    888
# Car overview - Ownership               32
# Car overview - Engine Displacement      4
# Car overview - Transmission             0
# Car overview - Year of Manufacture     20
# ...

# %%
df_new_car_overview_flattened.describe()
# Out:
#        Car overview - Year of Manufacture
# count                         8349.000000
# mean                          2016.547850
# std                              3.811882
# min                           2002.000000
# 25%                           2014.000000
# 50%                           2017.000000
# 75%                           2019.000000
# max                           2023.000000

# %%
df_new_car_overview_flattened['Car overview - Registration Year'] = df_new_car_overview_flattened['Car overview - Registration Year'].fillna(2016)
df_new_car_overview_flattened['Car overview - Year of Manufacture'] = df_new_car_overview_flattened['Car overview - Year of Manufacture'].fillna(2016)
df_new_car_overview_flattened.isnull().sum()
# Out:
# Car overview - Registration Year        0
# Car overview - Insurance Validity       4
# Car overview - Fuel Type                0
# Car overview - Seats                    6
# Car overview - Kms Driven               2
# Car overview - RTO                    888
# Car overview - Ownership               32
# Car overview - Engine Displacement      4
# Car overview - Transmission             0
# Car overview - Year of Manufacture      0
# dtype: int64

# %%
import re

# Function to extract year, converting input to string
def extract_year(value):
    # Convert value to string to handle different types
    value_str = str(value)
    # Match any year in the format YYYY or from a date string
    match = re.search(r'\b(19|20)\d{2}\b', value_str)
    if match:
        return int(match.group(0))
    return None  # Return None if no valid year is found

# Apply the function to extract the year for both columns
df_new_car_overview_flattened['Car overview - Registration Year'] = df_new_car_overview_flattened['Car overview - Registration Year'].apply(extract_year)
df_new_car_overview_flattened['Car overview - Year of Manufacture'] = df_new_car_overview_flattened['Car overview - Year of Manufacture'].apply(extract_year)

# Convert to int64 after extraction and filling
df_new_car_overview_flattened['Car overview - Registration Year'] = df_new_car_overview_flattened['Car overview - Registration Year'].astype('int64')
df_new_car_overview_flattened['Car overview - Year of Manufacture'] = df_new_car_overview_flattened['Car overview - Year of Manufacture'].astype('int64')

# Convert specific columns to 'category' type
df_new_car_overview_flattened['Car overview - Insurance Validity'] = df_new_car_overview_flattened['Car overview - Insurance Validity'].astype('category')
df_new_car_overview_flattened['Car overview - Fuel Type'] = df_new_car_overview_flattened['Car overview - Fuel Type'].astype('category')
df_new_car_overview_flattened['Car overview - Seats'] = df_new_car_overview_flattened['Car overview - Seats'].astype('category')
df_new_car_overview_flattened['Car overview - Ownership'] = df_new_car_overview_flattened['Car overview - Ownership'].astype('category')
df_new_car_overview_flattened['Car overview - Transmission'] = df_new_car_overview_flattened['Car overview - Transmission'].astype('category')
df_new_car_overview_flattened['Car overview - RTO'] = df_new_car_overview_flattened['Car overview - RTO'].astype('category')
df_new_car_overview_flattened['Car overview - Engine Displacement'] = df_new_car_overview_flattened['Car overview - Engine Displacement'].astype('category')

# Display the info of the updated DataFrame
df_new_car_overview_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Car overview - Registration Year    8369 non-null   int64
#  1   Car overview - Insurance Validity   8365 non-null   category
#  2   Car overview - Fuel Type            8369 non-null   category
#  3   Car overview - Seats                8363 non-null   category
#  4   Car overview - Kms Driven           8367 non-null   object
#  5   Car overview - RTO                  7481 non-null   category
#  6   Car overview - Ownership            8337 non-null   category
#  7   Car overview - Engine Displacement  8365 non-null   category
#  8   Car overview - Transmission         8369 non-null   category
#  9   Car overview - Year of Manufacture  8369 non-null   int64
# dtypes: category(7), int64(2), object(1)
# memory usage: 296.1+ KB

# %%
df_new_car_overview_flattened.isnull().sum()
# Out:
# Car overview - Registration Year        0
# Car overview - Insurance Validity       4
# Car overview - Fuel Type                0
# Car overview - Seats                    6
# Car overview - Kms Driven               2
# Car overview - RTO                    888
# Car overview - Ownership               32
# Car overview - Engine Displacement      4
# Car overview - Transmission             0
# Car overview - Year of Manufacture      0
# dtype: int64

# %%
# Display descriptive statistics for categorical columns
df_new_car_overview_flattened.describe(include=['category'])
# Out:
#        Car overview - Insurance Validity Car overview - Fuel Type  \
# count                               8365                     8369
# unique                                 7                        5
# top                Third Party insurance                   Petrol
# freq                                4055                     5554
#
#        Car overview - Seats Car overview - RTO Car overview - Ownership  \
# count                  8363               7481                     8337
# unique                    8                465                        5
# top                 5 Seats               WB02              First Owner
# freq                   7354                452                     5882
#
#        Car overview - Engine Displacement Car overview - Transmission
# count                                8365                        8369
# unique                                150                           2
# ...

# %%
df_new_car_overview_flattened['Car overview - Insurance Validity'] = df_new_car_overview_flattened['Car overview - Insurance Validity'].fillna('Third Party insurance')
df_new_car_overview_flattened['Car overview - Seats'] = df_new_car_overview_flattened['Car overview - Seats'].fillna('5 Seats')
df_new_car_overview_flattened['Car overview - Ownership'] = df_new_car_overview_flattened['Car overview - Ownership'].fillna('First Owner')
df_new_car_overview_flattened.isnull().sum()
# Out:
# Car overview - Registration Year        0
# Car overview - Insurance Validity       0
# Car overview - Fuel Type                0
# Car overview - Seats                    0
# Car overview - Kms Driven               2
# Car overview - RTO                    888
# Car overview - Ownership                0
# Car overview - Engine Displacement      4
# Car overview - Transmission             0
# Car overview - Year of Manufacture      0
# dtype: int64

# %%
df_new_car_overview_flattened['Car overview - RTO'] = df_new_car_overview_flattened['Car overview - RTO'].fillna('WB02')
df_new_car_overview_flattened['Car overview - Engine Displacement'] = df_new_car_overview_flattened['Car overview - Engine Displacement'].fillna('1197 cc')
df_new_car_overview_flattened.isnull().sum()
# Out:
# Car overview - Registration Year      0
# Car overview - Insurance Validity     0
# Car overview - Fuel Type              0
# Car overview - Seats                  0
# Car overview - Kms Driven             2
# Car overview - RTO                    0
# Car overview - Ownership              0
# Car overview - Engine Displacement    0
# Car overview - Transmission           0
# Car overview - Year of Manufacture    0
# dtype: int64

# %%
# Ensure the column is of string type to handle replacements correctly
df_new_car_overview_flattened['Car overview - Kms Driven'] = df_new_car_overview_flattened['Car overview - Kms Driven'].astype(str)

# Remove commas and non-numeric suffix, then handle NaN and convert to integers
df_new_car_overview_flattened['Car overview - Kms Driven'] = (
    df_new_car_overview_flattened['Car overview - Kms Driven']
    .str.replace(',', '', regex=False)  # Remove commas
    .str.replace(' Kms', '', regex=False)  # Remove ' Kms' suffix
    .str.replace('nan', '0', regex=False)  # Replace 'nan' string with '0'
    .replace('', '0')  # Replace any empty strings with '0'
    .fillna(0)  # Fill NaN values with 0
)

# Convert to integers
df_new_car_overview_flattened['Car overview - Kms Driven'] = df_new_car_overview_flattened['Car overview - Kms Driven'].astype(int)

# Display the updated DataFrame info
df_new_car_overview_flattened.info()

# Calculate the mean, ignoring 0 values
mean_kms = df_new_car_overview_flattened['Car overview - Kms Driven'][df_new_car_overview_flattened['Car overview - Kms Driven'] != 0].mean()

# Replace 0 values with the mean
df_new_car_overview_flattened['Car overview - Kms Driven'].replace(0, mean_kms, inplace=True)

# Convert the column to int after replacing
df_new_car_overview_flattened['Car overview - Kms Driven'] = df_new_car_overview_flattened['Car overview - Kms Driven'].astype(int)

# Display the updated DataFrame info
df_new_car_overview_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Car overview - Registration Year    8369 non-null   int64
#  1   Car overview - Insurance Validity   8369 non-null   category
#  2   Car overview - Fuel Type            8369 non-null   category
#  3   Car overview - Seats                8369 non-null   category
#  4   Car overview - Kms Driven           8369 non-null   int32
#  5   Car overview - RTO                  8369 non-null   category
#  6   Car overview - Ownership            8369 non-null   category
#  7   Car overview - Engine Displacement  8369 non-null   category
#  8   Car overview - Transmission         8369 non-null   category
#  9   Car overview - Year of Manufacture  8369 non-null   int64
# dtypes: category(7), int32(1), int64(2)
# memory usage: 263.4 KB
# ...

# %%
import pandas as pd
import json
import re

# Assuming merged_df is already defined and df_new_car_feature is extracted from it
df_new_car_feature = merged_df['new_car_feature']

# Function to parse entries
def parse_entry(entry):
    if isinstance(entry, str):
        entry = entry.replace("'", '"')
        entry = re.sub(r'([{,])\s*([^":\s]+)\s*:', r'\1"\2":', entry)
        return json.loads(entry)
    return entry

# Function to extract unique features from each row
def encode_features(row):
    unique_features = set()
    for feature in row.get('top', []):
        unique_features.add(feature['value'])
    for section in row.get('data', []):
        for feature in section.get('list', []):
            unique_features.add(feature['value'])
    return unique_features

# Collect unique features across all entries in the Series
all_unique_features = set()

# Collect all unique features
for row in df_new_car_feature:
    parsed_row = parse_entry(row)
    all_unique_features.update(encode_features(parsed_row))

# Convert to a sorted list
all_unique_features = sorted(all_unique_features)

# Create a list to hold the rows for the encoded DataFrame
encoded_rows = []

# Fill the DataFrame with binary values for each entry in the Series
for row in df_new_car_feature:
    parsed_row = parse_entry(row)
    feature_presence = {feature: (1 if feature in encode_features(parsed_row) else 0) for feature in all_unique_features}
    encoded_rows.append(feature_presence)

# Create the final DataFrame from the list of rows
df_car_feature_encoded = pd.DataFrame(encoded_rows, columns=all_unique_features)

# Display the resulting DataFrame
print(df_car_feature_encoded)
# Out:
#       Accessory Power Outlet  Active Noise Cancellation  \
# 0                          1                          0
# 1                          1                          0
# 2                          1                          0
# 3                          1                          0
# 4                          1                          0
# ...                      ...                        ...
# 8364                       1                          0
# 8365                       0                          0
# 8366                       1                          0
# 8367                       1                          0
# 8368                       1                          0
#
#       Adjustable Head Lights  Adjustable Headrest  Adjustable Seats  \
# 0                          1                    0                 1
# 1                          1                    0                 1
# 2                          1                    0                 1
# ...

# %%
# Create the final DataFrame from the list of rows
df_car_feature_encoded = pd.DataFrame(encoded_rows, columns=all_unique_features)

# Add the "No of Features" column, which counts the number of 1s in each row
df_car_feature_encoded['No of Features'] = df_car_feature_encoded.sum(axis=1)

# Display the resulting DataFrame
print(df_car_feature_encoded)
# Out:
#       Accessory Power Outlet  Active Noise Cancellation  \
# 0                          1                          0
# 1                          1                          0
# 2                          1                          0
# 3                          1                          0
# 4                          1                          0
# ...                      ...                        ...
# 8364                       1                          0
# 8365                       0                          0
# 8366                       1                          0
# 8367                       1                          0
# 8368                       1                          0
#
#       Adjustable Head Lights  Adjustable Headrest  Adjustable Seats  \
# 0                          1                    0                 1
# 1                          1                    0                 1
# 2                          1                    0                 1
# ...

# %%
df_car_feature_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Columns: 174 entries, Accessory Power Outlet to No of Features
# dtypes: int64(174)
# memory usage: 11.1 MB

# %%
# Print each column name and dtype manually
for col, dtype in df_car_feature_encoded.dtypes.items():
    print(f"{col}: {dtype}")
# Out:
# Accessory Power Outlet: int64
# Active Noise Cancellation: int64
# Adjustable Head Lights: int64
# Adjustable Headrest: int64
# Adjustable Seats: int64
# Adjustable Steering: int64
# Air Conditioner: int64
# Air Quality Control: int64
# Alloy Wheels: int64
# Android Auto: int64
# Anti Lock Braking System: int64
# Anti Pinch Power Windows: int64
# Anti Theft Alarm: int64
# Anti Theft Device: int64
# Apple Car Play: int64
# Audio System Remote Control: int64
# Automatic Driving Lights: int64
# Automatic Head Lamps: int64
# Battery Saver: int64
# Blind Spot Monitor: int64
# Bluetooth: int64
# Brake Assist: int64
# Cassette Player: int64
# Cd Changer: int64
# Cd Player: int64
# Centeral Locking: int64
# Centrally Mounted Fuel Tank: int64
# Child Safety Locks: int64
# Chrome Garnish: int64
# Chrome Grille: int64
# Cigarette Lighter: int64
# Clutch Lock: int64
# Compass: int64
# Cornering Foglamps: int64
# Cornering Headlamps: int64
# Crash Sensor: int64
# Cruise Control: int64
# ...

# %%
import pandas as pd
import ast  # Use ast for safer evaluation

# Extracting the 'new_car_specs' column from merged_df
df_new_car_specs = merged_df['new_car_specs']

# Safely evaluate the strings in the Series to convert them into dictionaries
s = [ast.literal_eval(i) for i in df_new_car_specs]
df_new_car_specs_1 = pd.DataFrame(s)

# Extract the 'top' and 'data' sections
df_new_car_specs_1_top = df_new_car_specs_1['top']
df_new_car_specs_1_data = df_new_car_specs_1['data']

# Function to convert list of dictionaries to a single dictionary with key-value pairs
def convert_to_dict(row):
    return {item['key']: item['value'] for item in row}

# Convert the 'top' section into a DataFrame
all_data_top = df_new_car_specs_1_top.apply(convert_to_dict)
df_new_car_specs_top_flattened = pd.DataFrame(all_data_top.tolist())

# Flatten the 'data' section
flattened_data_list = []  # This will store multiple rows of flattened data

# Iterate through each row in the Series for the 'data' section
for specs_list in df_new_car_specs_1_data:
    flattened_data = {}  # Temporary dictionary to store the flattened row

    # Iterate through each section in specs_list
    for section in specs_list:
        # Check if the section is a dictionary
        if isinstance(section, dict):
            # Iterate over each dictionary in the 'list' within this section
            for item in section['list']:
                # Create a column name by merging subHeading and key
                column_name = f"{section['subHeading']} - {item['key']}"
                # Set the value for this column in the flattened dictionary
                flattened_data[column_name] = item['value']

    # Append the flattened row to the list
    flattened_data_list.append(flattened_data)

# Convert the list of flattened dictionaries into a DataFrame
df_new_car_specs_data_flattened = pd.DataFrame(flattened_data_list)

df_new_car_specs_flattened = pd.concat([df_new_car_specs_top_flattened, df_new_car_specs_data_flattened], axis=1)

# Display the final merged DataFrame
print(df_new_car_specs_flattened)
# Out:
#          Mileage   Engine  Max Power    Torque Seats Wheel Size  \
# 0      23.1 kmpl   998 CC   67.04bhp      90Nm     5        NaN
# 1        17 kmpl  1497 CC  121.31bhp     150Nm     5         16
# 2     23.84 kmpl  1199 CC      84bhp     114Nm     5         14
# 3      19.1 kmpl  1197 CC   81.86bhp  113.75Nm     5         14
# 4     23.65 kmpl  1248 CC    88.5bhp     200Nm     5         16
# ...          ...      ...        ...       ...   ...        ...
# 8364  25.24 kmpl   998 CC   65.71bhp      89Nm     5        NaN
# 8365  22.74 kmpl   796 CC    47.3bhp      69Nm     5        NaN
# 8366  11.74 kmpl  1796 CC     186bhp     285Nm     5         17
# 8367   18.5 kmpl  1197 CC   85.80bhp     114Nm     5         14
# 8368  19.72 kmpl  1461 CC  108.45bhp     245Nm     5         16
#
#      Engine - Color      Engine - Engine Type Engine - Displacement  \
# 0             White               K10B Engine                   998
# ...

# %%
df_new_car_specs_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 41 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Mileage                                8082 non-null   object
#  1   Engine                                 8365 non-null   object
#  2   Max Power                              8309 non-null   object
#  3   Torque                                 8309 non-null   object
#  4   Seats                                  8364 non-null   object
#  5   Wheel Size                             5386 non-null   object
#  6   Engine - Color                         8366 non-null   object
#  7   Engine - Engine Type                   8074 non-null   object
#  8   Engine - Displacement                  8365 non-null   object
#  9   Engine - Max Power                     8309 non-null   object
# ...

# %%
df_new_car_merged_flattened = pd.concat([df_new_car_detail_flattened,df_new_car_overview_flattened,df_car_feature_encoded,df_new_car_specs_flattened], ignore_index=False, axis=1)
df_new_car_merged_flattened
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  120000       Manual        3  3rd Owner
# 1      0  Petrol        SUV   32706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback   11949       Manual        1  1st Owner
# 3      0  Petrol      Sedan   17794       Manual        1  1st Owner
# 4      0  Diesel        SUV   60000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 8364   0  Petrol  Hatchback   10000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  120000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan   50000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback   40000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  120000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# 0            Maruti         Maruti Celerio       2015  ...
# ...

# %%
import numpy as np
import pandas as pd

# Assuming df_new_car_merged_flattened exists, extract the required columns
df_new_car_merged_flattened_temp_1 = df_new_car_merged_flattened[['Mileage', 'Engine', 'Max Power', 'Torque', 'Seats', 'Wheel Size', 'ft', 'Car overview - Fuel Type']]

# Clean the Mileage column by removing units (km/kg and KMPL)
df_new_car_merged_flattened_temp_1['Mileage'] = df_new_car_merged_flattened_temp_1['Mileage'].str.replace(' km/kg', '', case=False)
df_new_car_merged_flattened_temp_1['Mileage'] = df_new_car_merged_flattened_temp_1['Mileage'].str.replace(' KMPL', '', case=False)

# Convert Mileage to numeric
df_new_car_merged_flattened_temp_1['Mileage'] = pd.to_numeric(df_new_car_merged_flattened_temp_1['Mileage'], errors='coerce')

# Conversion factors for CNG and LPG to kmpl
cng_to_kmpl = 1.39
lpg_to_kmpl = 1.82

# Apply the conversion to Mileage in kmpl based on Fuel Type
df_new_car_merged_flattened_temp_1['Mileage'] = np.where(df_new_car_merged_flattened_temp_1['Car overview - Fuel Type'] == 'CNG', 
                                                         df_new_car_merged_flattened_temp_1['Mileage'] * cng_to_kmpl,
                                                         np.where(df_new_car_merged_flattened_temp_1['Car overview - Fuel Type'] == 'LPG', 
                                                                  df_new_car_merged_flattened_temp_1['Mileage'] * lpg_to_kmpl,
                                                                  df_new_car_merged_flattened_temp_1['Mileage']))

# Rename columns in the temporary DataFrame
df_new_car_merged_flattened_temp_1.rename(columns={'Engine': 'Engine(CC)',
                                                   'Max Power': 'Max Power(bhp)',
                                                   'Torque': 'Torque(Nm)'}, inplace=True)

# Function to clean specific columns (remove units and convert to numeric)
def clean_column(df, column_name, remove_str, to_numeric=True):
    df[column_name] = df[column_name].astype(str)  # Convert to string to avoid errors
    df[column_name] = df[column_name].str.replace(remove_str, '', case=False).str.strip()  # Remove unwanted string
    if to_numeric:
        df[column_name] = pd.to_numeric(df[column_name], errors='coerce')  # Convert to numeric

# Clean Engine(CC), Max Power(bhp), Torque(Nm) columns
clean_column(df_new_car_merged_flattened_temp_1, 'Engine(CC)', 'CC')
clean_column(df_new_car_merged_flattened_temp_1, 'Max Power(bhp)', 'bhp')
clean_column(df_new_car_merged_flattened_temp_1, 'Torque(Nm)', 'Nm')

# Clean Seats column (convert to numeric)
df_new_car_merged_flattened_temp_1['Seats'] = pd.to_numeric(df_new_car_merged_flattened_temp_1['Seats'], errors='coerce')

# Clean Wheel Size column by removing 'R' and '"' and then convert to numeric
df_new_car_merged_flattened_temp_1['Wheel Size'] = df_new_car_merged_flattened_temp_1['Wheel Size'].astype(str)
df_new_car_merged_flattened_temp_1['Wheel Size'] = df_new_car_merged_flattened_temp_1['Wheel Size'].str.replace('R', '', case=False).str.replace('"', '').str.strip()
df_new_car_merged_flattened_temp_1['Wheel Size'] = pd.to_numeric(df_new_car_merged_flattened_temp_1['Wheel Size'], errors='coerce')

# List of columns to fill NaN values with their respective means
columns_to_fill = ['Mileage', 'Engine(CC)', 'Max Power(bhp)', 'Torque(Nm)', 'Seats', 'Wheel Size']

# Fill NaN values in specified columns with their mean values
for column in columns_to_fill:
    mean_value = df_new_car_merged_flattened_temp_1[column].mean()
    df_new_car_merged_flattened_temp_1[column].fillna(mean_value, inplace=True)

# Rename the same columns in the original DataFrame
df_new_car_merged_flattened.rename(columns={'Engine': 'Engine(CC)',
                                            'Max Power': 'Max Power(bhp)',
                                            'Torque': 'Torque(Nm)'}, inplace=True)

# Update the original DataFrame with the cleaned and transformed data
df_new_car_merged_flattened.update(df_new_car_merged_flattened_temp_1)

# Optional: Verify the updated columns for NaN values (should be 0 after filling)
print(df_new_car_merged_flattened[columns_to_fill].isnull().sum())

# Check the updated DataFrame
print(df_new_car_merged_flattened[columns_to_fill].head())
# Out:
# Mileage           0
# Engine(CC)        0
# Max Power(bhp)    0
# Torque(Nm)        0
# Seats             0
# Wheel Size        0
# dtype: int64
#   Mileage Engine(CC) Max Power(bhp) Torque(Nm) Seats Wheel Size
# 0    23.1      998.0          67.04       90.0   5.0  15.697549
# 1    17.0     1497.0         121.31      150.0   5.0       16.0
# 2   23.84     1199.0           84.0      114.0   5.0       14.0
# 3    19.1     1197.0          81.86     113.75   5.0       14.0
# 4   23.65     1248.0           88.5      200.0   5.0       16.0
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\3807995180.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import numpy as np
import pandas as pd

# Extract the relevant columns from df_new_car_merged_flattened
df_new_car_merged_flattened_temp_2 = df_new_car_merged_flattened[['Engine - Color', 'Engine - Engine Type', 'Engine - Displacement',
       'Engine - Max Power', 'Engine - Max Torque', 'Engine - No of Cylinder',
       'Engine - Values per Cylinder', 'Engine - Value Configuration',
       'Engine - Fuel Suppy System', 'Engine - BoreX Stroke',
       'Engine - Compression Ratio', 'Engine - Turbo Charger',
       'Engine - Super Charger']]

# Convert the relevant columns to 'category' data type
categorical_columns = [
    'Engine - Color', 'Engine - Engine Type', 'Engine - Value Configuration',
    'Engine - Fuel Suppy System', 'Engine - Turbo Charger', 'Engine - Super Charger',
    'Engine - Displacement', 'Engine - Max Power', 'Engine - Max Torque'
]

for column in categorical_columns:
    df_new_car_merged_flattened_temp_2[column] = df_new_car_merged_flattened_temp_2[column].astype('category')

# Fill missing values in categorical columns with the most frequent value (mode)
for column in categorical_columns:
    top_value = df_new_car_merged_flattened_temp_2[column].mode()[0]
    df_new_car_merged_flattened_temp_2[column].fillna(top_value, inplace=True)

# Additional categorical columns to clean
additional_categorical_columns = ['Engine - BoreX Stroke', 'Engine - Compression Ratio']

for column in additional_categorical_columns:
    top_value = df_new_car_merged_flattened_temp_2[column].mode()[0]
    df_new_car_merged_flattened_temp_2[column].fillna(top_value, inplace=True)

# Fill missing values in numeric columns with the 75th percentile
numeric_columns = ['Engine - No of Cylinder', 'Engine - Values per Cylinder']

for column in numeric_columns:
    seventy_five_percentile_value = df_new_car_merged_flattened_temp_2[column].quantile(0.75)
    df_new_car_merged_flattened_temp_2[column].fillna(seventy_five_percentile_value, inplace=True)

# Update the original DataFrame with cleaned data from df_new_car_merged_flattened_temp_2
columns_to_update = [
    'Engine - Color', 'Engine - Engine Type', 'Engine - Displacement', 'Engine - Max Power', 
    'Engine - Max Torque', 'Engine - No of Cylinder', 'Engine - Values per Cylinder', 
    'Engine - Value Configuration', 'Engine - Fuel Suppy System', 'Engine - BoreX Stroke', 
    'Engine - Compression Ratio', 'Engine - Turbo Charger', 'Engine - Super Charger'
]

df_new_car_merged_flattened.loc[df_new_car_merged_flattened_temp_2.index, columns_to_update] = df_new_car_merged_flattened_temp_2[columns_to_update]

# Verify the changes in the original DataFrame
print("Updated values:")
print(df_new_car_merged_flattened[columns_to_update].head())

# Check for any NaN values in the updated columns
print("\nCount of NaN values after update:")
print(df_new_car_merged_flattened[columns_to_update].isnull().sum())

# Display summary statistics for the updated columns
print("\nSummary statistics for updated columns:")
print(df_new_car_merged_flattened[columns_to_update].describe(include='all'))

# Optionally, compare original and updated values to see changes
for column in columns_to_update:
    changes = df_new_car_merged_flattened_temp_2[column].compare(df_new_car_merged_flattened[column], keep_shape=True, keep_equal=True)
    if not changes.empty:
        print(f"\nChanges in {column}:")
        print(changes)
# Out:
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\732265017.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_car_merged_flattened_temp_2[column] = df_new_car_merged_flattened_temp_2[column].astype('category')
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\732265017.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_car_merged_flattened_temp_2[column] = df_new_car_merged_flattened_temp_2[column].astype('category')
# ...

# %%
import pandas as pd

# Step 1: Extract the relevant columns for dimensions and weights
df_new_car_merged_flattened_temp_3 = df_new_car_merged_flattened[['Dimensions - Length', 'Dimensions - Width',
       'Dimensions - Height', 'Dimensions - Wheel Base',
       'Dimensions - Front Tread', 'Dimensions - Rear Tread',
       'Dimensions - Kerb Weight', 'Dimensions - Gross Weight']]

# Display the extracted DataFrame and info
print("Extracted Dimensions DataFrame:")
print(df_new_car_merged_flattened_temp_3)
df_new_car_merged_flattened_temp_3.info()

# Check for null values
print("\nNull values in each column:")
print(df_new_car_merged_flattened_temp_3.isnull().sum())

# Step 2: Define the columns to rename
dimension_columns = [
    'Dimensions - Length', 
    'Dimensions - Width', 
    'Dimensions - Height', 
    'Dimensions - Wheel Base', 
    'Dimensions - Front Tread', 
    'Dimensions - Rear Tread'
]

# Rename the columns by appending '(mm)' in the original DataFrame
df_new_car_merged_flattened.rename(columns={col: f"{col} (mm)" for col in dimension_columns}, inplace=True)

# Define the columns to rename for weight
weight_columns = [
    'Dimensions - Kerb Weight', 
    'Dimensions - Gross Weight'
]

# Rename the columns by appending '(kg)' in the original DataFrame
df_new_car_merged_flattened.rename(columns={col: f"{col} (kg)" for col in weight_columns}, inplace=True)

# Step 3: List of columns to clean by removing 'mm' and 'kg'
columns_to_clean = [
    'Dimensions - Length (mm)', 
    'Dimensions - Width (mm)', 
    'Dimensions - Height (mm)', 
    'Dimensions - Wheel Base (mm)', 
    'Dimensions - Front Tread (mm)', 
    'Dimensions - Rear Tread (mm)', 
    'Dimensions - Kerb Weight (kg)', 
    'Dimensions - Gross Weight (kg)'
]

# Remove 'mm' and 'kg' from the specified columns in the original DataFrame (if they were strings)
for column in columns_to_clean:
    if df_new_car_merged_flattened[column].dtype == object:  # Check if the column is of type string
        df_new_car_merged_flattened[column] = (
            df_new_car_merged_flattened[column]
            .str.replace('mm', '', case=False)
            .str.replace('kg', '', case=False)
            .str.strip()  # Remove leading/trailing spaces
        )

# Step 4: Convert columns to numeric in the original DataFrame
for column in columns_to_clean:
    df_new_car_merged_flattened[column] = pd.to_numeric(df_new_car_merged_flattened[column], errors='coerce')

# Verify the changes
print(df_new_car_merged_flattened[columns_to_clean].head())
df_new_car_merged_flattened.info()

# Step 5: Fill null values with the mean of each specified column in the original DataFrame
columns_to_fill = columns_to_clean  # Using the same columns to fill as we cleaned
for column in columns_to_fill:
    mean_value = df_new_car_merged_flattened[column].mean()  # Calculate mean
    df_new_car_merged_flattened[column].fillna(mean_value, inplace=True)  # Fill nulls with mean

# Verify that there are no more null values in the specified columns in the original DataFrame
print("\nNull values after filling in original DataFrame:")
print(df_new_car_merged_flattened[columns_to_fill].isnull().sum())

# Verify the changes in the original DataFrame
print("\nUpdated values in original DataFrame:")
print(df_new_car_merged_flattened[columns_to_fill].head())
print("\nInfo on updated columns in original DataFrame:")
df_new_car_merged_flattened[columns_to_fill].info()
# Out:
# Extracted Dimensions DataFrame:
#      Dimensions - Length Dimensions - Width Dimensions - Height  \
# 0                 3715mm             1635mm              1565mm
# 1                 3998mm             1765mm              1647mm
# 2                 3746mm             1647mm              1535mm
# 3                 3995mm             1660mm              1520mm
# 4                 4300mm             1785mm              1595mm
# ...                  ...                ...                 ...
# 8364              3695mm               1655                1555
# 8365              3395mm             1490mm              1475mm
# 8366              4591mm             1770mm              1447mm
# 8367              3775mm             1680mm              1620mm
# 8368              4315mm             1822mm              1695mm
#
#      Dimensions - Wheel Base Dimensions - Front Tread Dimensions - Rear Tread  \
# 0                     2425mm                   1420mm                  1410mm
# ...

# %%
import pandas as pd
import numpy as np

# Step 1: Extract the relevant columns for miscellaneous data
df_new_car_merged_flattened_temp_4 = df_new_car_merged_flattened[['Miscellaneous - Gear Box', 'Miscellaneous - Drive Type',
       'Miscellaneous - Seating Capacity', 'Miscellaneous - Steering Type',
       'Miscellaneous - Turning Radius', 'Miscellaneous - Front Brake Type',
       'Miscellaneous - Rear Brake Type', 'Miscellaneous - Top Speed',
       'Miscellaneous - Acceleration', 'Miscellaneous - Tyre Type',
       'Miscellaneous - No Door Numbers', 'Miscellaneous - Cargo Volumn',
       'Miscellaneous - Alloy Wheel Size']]

# Step 2: Function to clean and convert columns
def clean_and_convert(column, replacements, fill_method='mean'):
    # Clean the column
    cleaned_column = column.replace(replacements, regex=True)
    cleaned_column = pd.to_numeric(cleaned_column, errors='coerce')
    
    # Fill NaN values based on the specified method
    if fill_method == 'mean':
        mean_value = cleaned_column.mean()
        cleaned_column.fillna(mean_value, inplace=True)
    elif fill_method == 'top':
        top_value = cleaned_column.mode()[0]
        cleaned_column.fillna(top_value, inplace=True)
    elif fill_method == 'quantile':
        quantile_75 = cleaned_column.quantile(0.75)
        cleaned_column.fillna(quantile_75, inplace=True)
    
    return cleaned_column

# Step 3: Clean specific columns
# Clean the 'Turning Radius' column
df_new_car_merged_flattened_temp_4['Miscellaneous - Turning Radius'] = clean_and_convert(
    df_new_car_merged_flattened_temp_4['Miscellaneous - Turning Radius'],
    {'meters': '', 'metres': '', 'm': '', ' ': ''},
    fill_method='mean'
)

# Clean the 'Top Speed' column
df_new_car_merged_flattened_temp_4['Miscellaneous - Top Speed'] = clean_and_convert(
    df_new_car_merged_flattened_temp_4['Miscellaneous - Top Speed'],
    {'Km/h': '', 'Kmph': '', 'km/hr': '', ' ': ''},
    fill_method='mean'
)

# Clean the 'Acceleration' column
df_new_car_merged_flattened_temp_4['Miscellaneous - Acceleration'] = clean_and_convert(
    df_new_car_merged_flattened_temp_4['Miscellaneous - Acceleration'],
    {' Seconds': '', ' seconds': '', ' sec': '', 's': '', ' ': ''},
    fill_method='mean'
)

# Clean the 'Cargo Volume' column
df_new_car_merged_flattened_temp_4['Miscellaneous - Cargo Volumn'] = clean_and_convert(
    df_new_car_merged_flattened_temp_4['Miscellaneous - Cargo Volumn'],
    {' litres': '', ' liters': '', 'litres': '', 'liters': '', 'L': '', ' ': ''},
    fill_method='mean'
)

# Clean the 'Alloy Wheel Size' column
df_new_car_merged_flattened_temp_4['Miscellaneous - Alloy Wheel Size'] = clean_and_convert(
    df_new_car_merged_flattened_temp_4['Miscellaneous - Alloy Wheel Size'],
    {'R': '', ' ': ''},
    fill_method='mean'
)

# Step 4: Fill categorical columns with the most frequent value
columns_to_fill = [
    'Miscellaneous - Gear Box',
    'Miscellaneous - Drive Type',
    'Miscellaneous - Steering Type',
    'Miscellaneous - Front Brake Type',
    'Miscellaneous - Rear Brake Type',
    'Miscellaneous - Tyre Type'
]

top_values = {
    'Miscellaneous - Gear Box': '5 Speed',
    'Miscellaneous - Drive Type': 'FWD',
    'Miscellaneous - Steering Type': 'Power',
    'Miscellaneous - Front Brake Type': 'Disc',
    'Miscellaneous - Rear Brake Type': 'Drum',
    'Miscellaneous - Tyre Type': 'Tubeless,Radial'
}

# Fill each specified column with its top value
for column in columns_to_fill:
    df_new_car_merged_flattened_temp_4[column].fillna(top_values[column], inplace=True)

# Step 5: Fill 75th percentile for specific numeric columns
columns_to_fill_75_quantile = [
    'Miscellaneous - Seating Capacity',
    'Miscellaneous - No Door Numbers'
]

for column in columns_to_fill_75_quantile:
    df_new_car_merged_flattened_temp_4[column] = clean_and_convert(
        df_new_car_merged_flattened_temp_4[column],
        {},
        fill_method='quantile'
    )

# Step 6: Update the original DataFrame with cleaned values
df_new_car_merged_flattened.update(df_new_car_merged_flattened_temp_4)

# Step 7: Rename columns in the original DataFrame
columns_rename_mapping = {
    'Miscellaneous - Turning Radius': 'Miscellaneous - Turning Radius (m)',
    'Miscellaneous - Top Speed': 'Miscellaneous - Top Speed (Km/h)',
    'Miscellaneous - Acceleration': 'Miscellaneous - Acceleration (sec)',
    'Miscellaneous - Cargo Volumn': 'Miscellaneous - Cargo Volume (litres)',
    'Miscellaneous - Alloy Wheel Size': 'Miscellaneous - Alloy Wheel Size (inches)'
}

# Apply the renaming to the original DataFrame
df_new_car_merged_flattened.rename(columns=columns_rename_mapping, inplace=True)

# Step 8: Verify the changes in the original DataFrame
print("Updated column names in original DataFrame:")
print(df_new_car_merged_flattened.columns)

# Check if any NaN values are left
print("\nNull values in the original DataFrame after update and renaming:")
print(df_new_car_merged_flattened.isnull().sum())

# Optional: Display the updated data
print("\nSample data from updated columns:")
print(df_new_car_merged_flattened[list(columns_rename_mapping.values())].head())
# Out:
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\419510391.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_car_merged_flattened_temp_4['Miscellaneous - Turning Radius'] = clean_and_convert(
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\419510391.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_car_merged_flattened_temp_4['Miscellaneous - Top Speed'] = clean_and_convert(
# ...

# %%
df_new_car_merged_flattened
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  120000       Manual        3  3rd Owner
# 1      0  Petrol        SUV   32706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback   11949       Manual        1  1st Owner
# 3      0  Petrol      Sedan   17794       Manual        1  1st Owner
# 4      0  Diesel        SUV   60000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 8364   0  Petrol  Hatchback   10000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  120000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan   50000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback   40000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  120000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# 0            Maruti         Maruti Celerio       2015  ...
# ...

# %%
df_new_car_merged_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Columns: 239 entries, it to Dimensions - Ground Clearance Unladen
# dtypes: category(14), float64(11), int32(2), int64(180), object(32)
# memory usage: 14.6+ MB

# %%
# Print each column name and dtype manually
for col, dtype in df_new_car_merged_flattened.dtypes.items():
    print(f"{col}: {dtype}")
# Out:
# it: int64
# ft: category
# bt: category
# km: int32
# transmission: category
# ownerNo: int64
# owner: category
# oem: category
# model: category
# modelYear: int64
# centralVariantId: int64
# variantName: category
# price: object
# price_cleaned: float64
# Car overview - Registration Year: int64
# Car overview - Insurance Validity: category
# Car overview - Fuel Type: category
# Car overview - Seats: category
# Car overview - Kms Driven: int32
# Car overview - RTO: category
# Car overview - Ownership: category
# Car overview - Engine Displacement: category
# Car overview - Transmission: category
# Car overview - Year of Manufacture: int64
# Accessory Power Outlet: int64
# Active Noise Cancellation: int64
# Adjustable Head Lights: int64
# Adjustable Headrest: int64
# Adjustable Seats: int64
# Adjustable Steering: int64
# Air Conditioner: int64
# Air Quality Control: int64
# Alloy Wheels: int64
# Android Auto: int64
# Anti Lock Braking System: int64
# Anti Pinch Power Windows: int64
# ...

# %%
# Get the names of object columns
object_column_names = df_new_car_merged_flattened.select_dtypes(include='object').columns
print(object_column_names)
# Out:
# Index(['price', 'Mileage', 'Engine(CC)', 'Max Power(bhp)', 'Torque(Nm)',
#        'Seats', 'Wheel Size', 'Engine - Color', 'Engine - Engine Type',
#        'Engine - Displacement', 'Engine - Max Power', 'Engine - Max Torque',
#        'Engine - Value Configuration', 'Engine - Fuel Suppy System',
#        'Engine - BoreX Stroke', 'Engine - Compression Ratio',
#        'Engine - Turbo Charger', 'Engine - Super Charger',
#        'Miscellaneous - Gear Box', 'Miscellaneous - Drive Type',
#        'Miscellaneous - Seating Capacity', 'Miscellaneous - Steering Type',
#        'Miscellaneous - Turning Radius (m)',
#        'Miscellaneous - Front Brake Type', 'Miscellaneous - Rear Brake Type',
#        'Miscellaneous - Top Speed (Km/h)',
#        'Miscellaneous - Acceleration (sec)', 'Miscellaneous - Tyre Type',
#        'Miscellaneous - No Door Numbers',
#        'Miscellaneous - Cargo Volume (litres)',
#        'Miscellaneous - Alloy Wheel Size (inches)',
# ...

# %%
# Convert the 'Engine(CC)' column to float in the original DataFrame



df_new_car_merged_flattened['Max Power(bhp)'] = df_new_car_merged_flattened['Max Power(bhp)'].astype('float64')
df_new_car_merged_flattened['Miscellaneous - Turning Radius (m)'] = df_new_car_merged_flattened['Miscellaneous - Turning Radius (m)'].astype('float64')
df_new_car_merged_flattened['Miscellaneous - Acceleration (sec)'] = df_new_car_merged_flattened['Miscellaneous - Acceleration (sec)'].astype('float64')

df_new_car_merged_flattened['Engine(CC)'] = df_new_car_merged_flattened['Engine(CC)'].astype('int64')
df_new_car_merged_flattened['Torque(Nm)'] = df_new_car_merged_flattened['Torque(Nm)'].astype('int64')
df_new_car_merged_flattened['Seats'] = df_new_car_merged_flattened['Seats'].astype('int64')
df_new_car_merged_flattened['Wheel Size'] = df_new_car_merged_flattened['Wheel Size'].astype('int64')
df_new_car_merged_flattened['Engine - Displacement'] = df_new_car_merged_flattened['Engine - Displacement'].astype('int64')
df_new_car_merged_flattened['Miscellaneous - Seating Capacity'] = df_new_car_merged_flattened['Miscellaneous - Seating Capacity'].astype('int64')
df_new_car_merged_flattened['Miscellaneous - Top Speed (Km/h)'] = df_new_car_merged_flattened['Miscellaneous - Top Speed (Km/h)'].astype('int64')
df_new_car_merged_flattened['Miscellaneous - No Door Numbers'] = df_new_car_merged_flattened['Miscellaneous - No Door Numbers'].astype('int64')
df_new_car_merged_flattened['Miscellaneous - Cargo Volume (litres)'] = df_new_car_merged_flattened['Miscellaneous - Cargo Volume (litres)'].astype('int64')
df_new_car_merged_flattened['Miscellaneous - Alloy Wheel Size (inches)'] = df_new_car_merged_flattened['Miscellaneous - Alloy Wheel Size (inches)'].astype('int64')


df_new_car_merged_flattened['Engine - Color'] = df_new_car_merged_flattened['Engine - Color'].astype('category')
df_new_car_merged_flattened['Engine - Engine Type'] = df_new_car_merged_flattened['Engine - Engine Type'].astype('category')
df_new_car_merged_flattened['Engine - Color'] = df_new_car_merged_flattened['Engine - Color'].astype('category')
df_new_car_merged_flattened['Engine - Engine Type'] = df_new_car_merged_flattened['Engine - Engine Type'].astype('category')
df_new_car_merged_flattened['Engine - Value Configuration'] = df_new_car_merged_flattened['Engine - Value Configuration'].astype('category')
df_new_car_merged_flattened['Engine - Fuel Suppy System'] = df_new_car_merged_flattened['Engine - Fuel Suppy System'].astype('category')
df_new_car_merged_flattened['Engine - Super Charger'] = df_new_car_merged_flattened['Engine - Super Charger'].astype('category')
df_new_car_merged_flattened['Miscellaneous - Gear Box'] = df_new_car_merged_flattened['Miscellaneous - Gear Box'].astype('category')
df_new_car_merged_flattened['Miscellaneous - Drive Type'] = df_new_car_merged_flattened['Miscellaneous - Drive Type'].astype('category')
df_new_car_merged_flattened['Miscellaneous - Steering Type'] = df_new_car_merged_flattened['Miscellaneous - Steering Type'].astype('category')
df_new_car_merged_flattened['Miscellaneous - Front Brake Type'] = df_new_car_merged_flattened['Miscellaneous - Front Brake Type'].astype('category')
df_new_car_merged_flattened['Miscellaneous - Rear Brake Type'] = df_new_car_merged_flattened['Miscellaneous - Rear Brake Type'].astype('category')
df_new_car_merged_flattened['Miscellaneous - Tyre Type'] = df_new_car_merged_flattened['Miscellaneous - Tyre Type'].astype('category')

# Get the names of object columns
object_column_names = df_new_car_merged_flattened.select_dtypes(include='object').columns
print(object_column_names)
# Out:
# Index(['price', 'Mileage', 'Engine - Max Power', 'Engine - Max Torque',
#        'Engine - BoreX Stroke', 'Engine - Compression Ratio',
#        'Engine - Turbo Charger', 'Dimensions - Ground Clearance Unladen'],
#       dtype='object')

# %%
df_new_car_merged_flattened['Dimensions - Ground Clearance Unladen'].unique()
# Out:
# array([nan, '190mm', '205', '209 mm', '155mm', '120mm', '192mm', '210mm',
#        '160', '110mm', '185mm', '178mm', '116mm', '145mm', '200mm', '170',
#        '184mm', '180mm', '140mm', '170mm', '210 mm', '91mm', '180',
#        '175mm', '205mm', '165', '156mm'], dtype=object)

# %%
# Define the function to clean the column
def clean_dimension_data(column):
    # Remove 'mm', spaces, and convert to numeric
    cleaned_column = column.replace({'mm': '', ' ': ''}, regex=True)
    cleaned_column = pd.to_numeric(cleaned_column, errors='coerce')  # Convert to numeric, forcing errors to NaN
    
    # Fill NaN values with the mean
    mean_value = cleaned_column.mean()
    cleaned_column.fillna(mean_value, inplace=True)
    
    return cleaned_column

# Apply the cleaning function to the specific column in the original DataFrame
df_new_car_merged_flattened['Dimensions - Ground Clearance Unladen'] = clean_dimension_data(df_new_car_merged_flattened['Dimensions - Ground Clearance Unladen'])

# Verify the cleaned column
print(df_new_car_merged_flattened['Dimensions - Ground Clearance Unladen'].unique())
print(df_new_car_merged_flattened['Dimensions - Ground Clearance Unladen'].head())
# Out:
# [175.10097087 190.         205.         209.         155.
#  120.         192.         210.         160.         110.
#  185.         178.         116.         145.         200.
#  170.         184.         180.         140.          91.
#  175.         165.         156.        ]
# 0    175.100971
# 1    175.100971
# 2    175.100971
# 3    175.100971
# 4    175.100971
# Name: Dimensions - Ground Clearance Unladen, dtype: float64

# %%
# Get the names of object columns
object_column_names = df_new_car_merged_flattened.select_dtypes(include='object').columns
print(object_column_names)
# Out:
# Index(['price', 'Mileage', 'Engine - Max Power', 'Engine - Max Torque',
#        'Engine - BoreX Stroke', 'Engine - Compression Ratio',
#        'Engine - Turbo Charger'],
#       dtype='object')

# %%
df_new_car_merged_flattened.isnull().sum()
# Out:
# it                                           0
# ft                                           0
# bt                                           0
# km                                           0
# transmission                                 0
#                                             ..
# Miscellaneous - Tyre Type                    0
# Miscellaneous - No Door Numbers              0
# Miscellaneous - Cargo Volume (litres)        0
# Miscellaneous - Alloy Wheel Size (inches)    0
# Dimensions - Ground Clearance Unladen        0
# Length: 239, dtype: int64

# %%
# Get columns with null values
null_columns = df_new_car_merged_flattened.isnull().sum()

# Filter to show only columns with null values
null_columns = null_columns[null_columns > 0]

# Display columns with null values
print(null_columns)
# Out:
# Series([], dtype: int64)

# %%
df_new_car_merged_flattened['City']=merged_df['City']
df_new_car_merged_flattened['City'] = df_new_car_merged_flattened['City'].astype('category')
df_new_car_merged_flattened['City'].info()
df_new_car_merged_flattened['City']
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8369 entries, 0 to 8368
# Series name: City
# Non-Null Count  Dtype
# --------------  -----
# 8369 non-null   category
# dtypes: category(1)
# memory usage: 8.5 KB
# 0       Bangalore
# 1       Bangalore
# 2       Bangalore
# 3       Bangalore
# 4       Bangalore
#           ...
# 8364      Kolkata
# 8365      Kolkata
# 8366      Kolkata
# 8367      Kolkata
# 8368      Kolkata
# Name: City, Length: 8369, dtype: category
# Categories (6, object): ['Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Jaipur', 'Kolkata']

# %%
df_new_car_merged_flattened
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  120000       Manual        3  3rd Owner
# 1      0  Petrol        SUV   32706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback   11949       Manual        1  1st Owner
# 3      0  Petrol      Sedan   17794       Manual        1  1st Owner
# 4      0  Diesel        SUV   60000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 8364   0  Petrol  Hatchback   10000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  120000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan   50000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback   40000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  120000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# 0            Maruti         Maruti Celerio       2015  ...
# ...

# %%
df_for_EDA=df_new_car_merged_flattened[['it',
'bt',
'ownerNo',
'oem',
'model',
'modelYear',
'price_cleaned',
'Car overview - Registration Year',
'Car overview - Kms Driven',
'Car overview - Insurance Validity',
'Car overview - Fuel Type',
'Car overview - Transmission',
'Car overview - Year of Manufacture',
'No of Features',
'Mileage',
'Engine(CC)',
'Max Power(bhp)',
'Torque(Nm)',
'Seats',
'Engine - Values per Cylinder',
'Miscellaneous - Tyre Type',
'City']]
df_for_EDA
# Out:
#       it         bt  ownerNo            oem                  model  modelYear  \
# 0      0  Hatchback        3         Maruti         Maruti Celerio       2015
# 1      0        SUV        2           Ford          Ford Ecosport       2018
# 2      0  Hatchback        1           Tata             Tata Tiago       2018
# 3      0      Sedan        1        Hyundai          Hyundai Xcent       2014
# 4      0        SUV        1         Maruti     Maruti SX4 S Cross       2015
# ...   ..        ...      ...            ...                    ...        ...
# 8364   0  Hatchback        1         Maruti         Maruti Celerio       2022
# 8365   0  Hatchback        1         Maruti        Maruti Alto 800       2014
# 8366   0      Sedan        3  Mercedes-Benz  Mercedes-Benz C-Class       2011
# 8367   0  Hatchback        1         Maruti            Maruti Ritz       2012
# 8368   0        SUV        2        Renault         Renault Duster       2017
#
# ...

# %%
df_for_EDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   it                                  8369 non-null   int64
#  1   bt                                  8369 non-null   category
#  2   ownerNo                             8369 non-null   int64
#  3   oem                                 8369 non-null   category
#  4   model                               8369 non-null   category
#  5   modelYear                           8369 non-null   int64
#  6   price_cleaned                       8369 non-null   float64
#  7   Car overview - Registration Year    8369 non-null   int64
#  8   Car overview - Kms Driven           8369 non-null   int32
#  9   Car overview - Insurance Validity   8369 non-null   category
#  10  Car overview - Fuel Type            8369 non-null   category
# ...

# %%
df_for_EDA['Mileage'] = df_for_EDA['Mileage'].astype('float64')
print(df_for_EDA.info())
print(df_for_EDA.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   it                                  8369 non-null   int64
#  1   bt                                  8369 non-null   category
#  2   ownerNo                             8369 non-null   int64
#  3   oem                                 8369 non-null   category
#  4   model                               8369 non-null   category
#  5   modelYear                           8369 non-null   int64
#  6   price_cleaned                       8369 non-null   float64
#  7   Car overview - Registration Year    8369 non-null   int64
#  8   Car overview - Kms Driven           8369 non-null   int32
#  9   Car overview - Insurance Validity   8369 non-null   category
#  10  Car overview - Fuel Type            8369 non-null   category
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math

# Define categorical columns and numerical column to plot
categorical_columns = ['bt', 'oem', 'model', 'Car overview - Insurance Validity', 'Car overview - Fuel Type','Car overview - Transmission','Miscellaneous - Tyre Type','City']  # Replace with your categorical columns
numerical_column = 'price_cleaned'  # Replace with the numerical column of your choice

# Number of rows and columns for the plot grid
n_cols = 3  # Adjust number of columns based on preference
n_rows = math.ceil(len(categorical_columns) / n_cols)  # Calculate number of rows

# Set the figure size and layout
plt.figure(figsize=(15, 15))

# Loop through each categorical column and create bar plots
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.barplot(x=col, y=numerical_column, data=df_for_EDA)
    plt.title(f'Mean {numerical_column} across {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()

# Display the plots
plt.show()
# Out:
# C:\Users\Bhuvanesh\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Bhuvanesh\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_for_EDA is your original DataFrame, filter only the numerical columns
df_numerical_only = df_for_EDA.select_dtypes(include=['float64', 'int64','int32'])

# Step 1: Calculate the correlation matrix for numerical columns
correlation_matrix = df_numerical_only.corr()

# Set the size of the heatmap
plt.figure(figsize=(12, 8))

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', 
            square=True, linewidths=0.5, cbar_kws={"shrink": .8})

# Set the title
plt.title("Correlation Matrix Heatmap for Numerical Columns")

# Show the plot
plt.tight_layout()  # Ensures layout fits well
plt.show()
# Out:
# C:\Users\Bhuvanesh\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histograms for numerical columns
df_numerical_only.hist(bins=30, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Features', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the number of rows and columns for the subplots
num_columns = len(df_numerical_only.select_dtypes(include=['float64', 'int64']).columns)
num_rows = (num_columns // 4) + (num_columns % 4 > 0)  # Calculate required rows

plt.figure(figsize=(15, 5 * num_rows))  # Adjust height based on number of rows

# Create a box plot for each numerical column
for i, column in enumerate(df_numerical_only.select_dtypes(include=['float64', 'int64']).columns, 1):
    plt.subplot(num_rows, 4, i)  # Adjust subplot grid
    sns.boxplot(y=df_numerical_only[column])
    plt.title(column)

plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the number of rows and columns for the subplots
numerical_columns = df_numerical_only.select_dtypes(include=['float64', 'int64']).columns
num_columns = len(numerical_columns)
num_rows = (num_columns // 4) + (num_columns % 4 > 0)  # Calculate required rows

plt.figure(figsize=(15, 5 * num_rows))  # Adjust height based on number of rows

# Create a scatter plot for each numerical column
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(num_rows, 4, i)
    sns.scatterplot(data=df_numerical_only, x=column, y='price_cleaned')
    plt.title(f'Scatter Plot between {column} and price_cleaned')
    plt.xlabel(column)
    plt.ylabel('price_cleaned')

plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.show()

# %%
# Using IQR to identify outliers
Q1 = df_numerical_only.quantile(0.25)
Q3 = df_numerical_only.quantile(0.75)
IQR = Q3 - Q1

# Outlier detection
outliers = ((df_numerical_only < (Q1 - 1.5 * IQR)) | (df_numerical_only > (Q3 + 1.5 * IQR))).sum()
print("Outliers detected:\n", outliers[outliers > 0])
# Out:
# Outliers detected:
#  ownerNo                                 99
# modelYear                              132
# price_cleaned                          878
# Car overview - Registration Year       110
# Car overview - Kms Driven               48
# Car overview - Year of Manufacture     112
# No of Features                         100
# Mileage                                195
# Engine(CC)                            1527
# Max Power(bhp)                         615
# Torque(Nm)                             641
# Seats                                 1009
# Engine - Values per Cylinder           411
# dtype: int64

# %%
# Update the 'ownerNo' column where it is 0
df_numerical_only['ownerNo'] = df_numerical_only['ownerNo'].replace(0, 1)
df_numerical_only['ownerNo'].describe()
# Out:
# count    8369.000000
# mean        1.363962
# std         0.636803
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: ownerNo, dtype: float64

# %%
# Using IQR to identify outliers
Q1 = df_numerical_only.quantile(0.25)
Q3 = df_numerical_only.quantile(0.75)
IQR = Q3 - Q1

# Outlier detection
outliers = ((df_numerical_only < (Q1 - 1.5 * IQR)) | (df_numerical_only > (Q3 + 1.5 * IQR))).sum()
print("Outliers detected:\n", outliers[outliers > 0])
# Out:
# Outliers detected:
#  ownerNo                                 99
# modelYear                              132
# price_cleaned                          878
# Car overview - Registration Year       110
# Car overview - Kms Driven               48
# Car overview - Year of Manufacture     112
# No of Features                         100
# Mileage                                195
# Engine(CC)                            1527
# Max Power(bhp)                         615
# Torque(Nm)                             641
# Seats                                 1009
# Engine - Values per Cylinder           411
# dtype: int64

# %%
print(df_numerical_only['modelYear'].describe())
print(df_numerical_only['Car overview - Year of Manufacture'].describe())
# Out:
# count    8369.000000
# mean     2016.503286
# std         3.921465
# min      1985.000000
# 25%      2014.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2023.000000
# Name: modelYear, dtype: float64
# count    8369.000000
# mean     2016.546541
# std         3.807418
# min      2002.000000
# 25%      2014.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2023.000000
# Name: Car overview - Year of Manufacture, dtype: float64

# %%
# Update modelYear where the value is less than 2002 with the corresponding value from Car overview - Year of Manufacture
df_numerical_only.loc[df_numerical_only['modelYear'] < 2002, 'modelYear'] = df_numerical_only['Car overview - Year of Manufacture']

# Print the updated modelYear column
print(df_numerical_only['modelYear'].describe())
# Out:
# count    8369.000000
# mean     2016.546541
# std         3.807418
# min      2002.000000
# 25%      2014.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2023.000000
# Name: modelYear, dtype: float64

# %%
# Using IQR to identify outliers
Q1 = df_numerical_only.quantile(0.25)
Q3 = df_numerical_only.quantile(0.75)
IQR = Q3 - Q1

# Outlier detection
outliers = ((df_numerical_only < (Q1 - 1.5 * IQR)) | (df_numerical_only > (Q3 + 1.5 * IQR))).sum()
print("Outliers detected:\n", outliers[outliers > 0])
# Out:
# Outliers detected:
#  ownerNo                                 99
# modelYear                              112
# price_cleaned                          878
# Car overview - Registration Year       110
# Car overview - Kms Driven               48
# Car overview - Year of Manufacture     112
# No of Features                         100
# Mileage                                195
# Engine(CC)                            1527
# Max Power(bhp)                         615
# Torque(Nm)                             641
# Seats                                 1009
# Engine - Values per Cylinder           411
# dtype: int64

# %%
df_numerical_only['Engine(CC)'].describe()
# Out:
# count    8369.000000
# mean     1424.735572
# std       477.514975
# min         0.000000
# 25%      1197.000000
# 50%      1248.000000
# 75%      1498.000000
# max      5000.000000
# Name: Engine(CC), dtype: float64

# %%
# Calculate the mean of the Engine(CC) column
mean_engine_cc = df_numerical_only['Engine(CC)'].mean()

# Update Engine(CC) where Engine(CC) is 0
df_numerical_only.loc[df_numerical_only['Engine(CC)'] < 1197, 'Engine(CC)'] = mean_engine_cc
df_numerical_only.loc[df_numerical_only['Engine(CC)'] > 1498, 'Engine(CC)'] = 1498


# Print the summary statistics of the Engine(CC) column
print(df_numerical_only['Engine(CC)'].describe())
# Out:
# count    8369.000000
# mean     1376.767259
# std       126.913612
# min      1197.000000
# 25%      1199.000000
# 50%      1424.735572
# 75%      1498.000000
# max      1498.000000
# Name: Engine(CC), dtype: float64
# C:\Users\Bhuvanesh\AppData\Local\Temp\ipykernel_8956\3952924680.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1424.7355717528976' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_numerical_only.loc[df_numerical_only['Engine(CC)'] < 1197, 'Engine(CC)'] = mean_engine_cc

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_numerical_only['price_cleaned'].quantile(0.25)
Q3 = df_numerical_only['price_cleaned'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Drop the rows where price_cleaned is an outlier
df_numerical_only = df_numerical_only[
    (df_numerical_only['price_cleaned'] >= lower_bound) & 
    (df_numerical_only['price_cleaned'] <= upper_bound)
]

# Print the number of rows remaining
print(f'Remaining rows after dropping outliers: {len(df_numerical_only)}')
# Out:
# Remaining rows after dropping outliers: 7491

# %%
# Using IQR to identify outliers
Q1 = df_numerical_only.quantile(0.25)
Q3 = df_numerical_only.quantile(0.75)
IQR = Q3 - Q1

# Outlier detection
outliers = ((df_numerical_only < (Q1 - 1.5 * IQR)) | (df_numerical_only > (Q3 + 1.5 * IQR))).sum()
print("Outliers detected:\n", outliers[outliers > 0])
# Out:
# Outliers detected:
#  ownerNo                                97
# modelYear                             112
# price_cleaned                         351
# Car overview - Registration Year      110
# Car overview - Kms Driven              56
# Car overview - Year of Manufacture    112
# No of Features                         72
# Mileage                               149
# Max Power(bhp)                        308
# Torque(Nm)                            483
# Seats                                 739
# Engine - Values per Cylinder          408
# dtype: int64

# %%
import numpy as np

# Define the outlier detection function
def drop_outliers(df, columns):
    for column in columns:
        lower_bound = df[column].quantile(0.01)
        upper_bound = df[column].quantile(0.99)
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# List of columns to check for outliers
outlier_columns = ['ownerNo', 'modelYear', 'price_cleaned', 'Car overview - Registration Year', 
                   'Car overview - Kms Driven', 'Car overview - Year of Manufacture', 
                   'No of Features', 'Mileage', 'Engine(CC)', 'Max Power(bhp)', 
                   'Torque(Nm)', 'Seats']

# Drop outliers
df_cleaned = drop_outliers(df_numerical_only, outlier_columns)

# Print the shape of the cleaned DataFrame
print(df_cleaned.shape)
# Out:
# (6505, 14)

# %%
# Using IQR to identify outliers
Q1 = df_cleaned.quantile(0.25)
Q3 = df_cleaned.quantile(0.75)
IQR = Q3 - Q1

# Outlier detection
outliers = ((df_cleaned < (Q1 - 1.5 * IQR)) | (df_cleaned > (Q3 + 1.5 * IQR))).sum()
print("Outliers detected:\n", outliers[outliers > 0])
# Out:
# Outliers detected:
#  ownerNo                          50
# price_cleaned                   238
# Car overview - Kms Driven        65
# Mileage                          50
# Max Power(bhp)                  199
# Torque(Nm)                      306
# Seats                           489
# Engine - Values per Cylinder    301
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Step 1: Calculate the correlation matrix for numerical columns
correlation_matrix = df_cleaned.corr()

# Set the size of the heatmap
plt.figure(figsize=(12, 8))

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', 
            square=True, linewidths=0.5, cbar_kws={"shrink": .8})

# Set the title
plt.title("Correlation Matrix Heatmap for Numerical Columns")

# Show the plot
plt.tight_layout()  # Ensures layout fits well
plt.show()
# Out:
# C:\Users\Bhuvanesh\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histograms for numerical columns
df_cleaned.hist(bins=30, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Features', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the number of rows and columns for the subplots
num_columns = len(df_cleaned.select_dtypes(include=['float64', 'int64', 'int32']).columns)
num_rows = (num_columns // 4) + (num_columns % 4 > 0)  # Calculate required rows

plt.figure(figsize=(15, 5 * num_rows))  # Adjust height based on number of rows

# Create a box plot for each numerical column
for i, column in enumerate(df_cleaned.select_dtypes(include=['float64', 'int64']).columns, 1):
    plt.subplot(num_rows, 4, i)  # Adjust subplot grid
    sns.boxplot(y=df_cleaned[column])
    plt.title(column)

plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the number of rows and columns for the subplots
numerical_columns = df_cleaned.select_dtypes(include=['float64', 'int64']).columns
num_columns = len(numerical_columns)
num_rows = (num_columns // 4) + (num_columns % 4 > 0)  # Calculate required rows

plt.figure(figsize=(15, 5 * num_rows))  # Adjust height based on number of rows

# Create a scatter plot for each numerical column
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(num_rows, 4, i)
    sns.scatterplot(data=df_cleaned, x=column, y='price_cleaned')
    plt.title(f'Scatter Plot between {column} and price_cleaned')
    plt.xlabel(column)
    plt.ylabel('price_cleaned')

plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.show()

# %%
df_for_EDA
# Out:
#       it         bt  ownerNo            oem                  model  modelYear  \
# 0      0  Hatchback        3         Maruti         Maruti Celerio       2015
# 1      0        SUV        2           Ford          Ford Ecosport       2018
# 2      0  Hatchback        1           Tata             Tata Tiago       2018
# 3      0      Sedan        1        Hyundai          Hyundai Xcent       2014
# 4      0        SUV        1         Maruti     Maruti SX4 S Cross       2015
# ...   ..        ...      ...            ...                    ...        ...
# 8364   0  Hatchback        1         Maruti         Maruti Celerio       2022
# 8365   0  Hatchback        1         Maruti        Maruti Alto 800       2014
# 8366   0      Sedan        3  Mercedes-Benz  Mercedes-Benz C-Class       2011
# 8367   0  Hatchback        1         Maruti            Maruti Ritz       2012
# 8368   0        SUV        2        Renault         Renault Duster       2017
#
# ...

# %%
import pandas as pd

# Ensure the indices match for merging
df_cleaned.reset_index(drop=True, inplace=True)
df_for_EDA.reset_index(drop=True, inplace=True)

# Update the original DataFrame with values from the cleaned DataFrame
for column in df_cleaned.columns:
    df_for_EDA.loc[df_cleaned.index, column] = df_cleaned[column]

# Retain only the rows from df_cleaned in df_for_EDA
df_for_EDA_updated = df_for_EDA.loc[df_cleaned.index]

# Now df_for_EDA_updated contains only the updated rows
print(df_for_EDA_updated)
# Out:
#       it         bt  ownerNo      oem               model  modelYear  \
# 0      0  Hatchback        3   Maruti      Maruti Celerio       2015
# 1      0        SUV        2     Ford       Ford Ecosport       2018
# 2      0  Hatchback        1     Tata          Tata Tiago       2018
# 3      0      Sedan        1  Hyundai       Hyundai Xcent       2014
# 4      0        SUV        1   Maruti  Maruti SX4 S Cross       2015
# ...   ..        ...      ...      ...                 ...        ...
# 6500   0        MUV        1   Maruti       Maruti Ertiga       2009
# 6501   0        SUV        1      Kia          Kia Seltos       2022
# 6502   0        SUV        1     Ford       Ford Ecosport       2014
# 6503   0        SUV        1   Nissan      Nissan Terrano       2012
# 6504   0  Hatchback        2  Hyundai         Hyundai i20       2017
#
#       price_cleaned  Car overview - Registration Year  \
# 0          400000.0                              2015
# ...

# %%
df_for_EDA_updated = df_for_EDA_updated.drop(
    ['it', 'bt', 'model', 'Car overview - Registration Year', 
     'Car overview - Year of Manufacture', 'Max Power(bhp)', 
     'Torque(Nm)', 'Seats', 'Engine - Values per Cylinder', 
     'Miscellaneous - Tyre Type'], 
    axis=1, 
    errors='ignore'
)

# %%
print(df_for_EDA_updated.columns.tolist())
# Out:
# ['ownerNo', 'oem', 'modelYear', 'price_cleaned', 'Car overview - Kms Driven', 'Car overview - Insurance Validity', 'Car overview - Fuel Type', 'Car overview - Transmission', 'No of Features', 'Mileage', 'Engine(CC)', 'City']

# %%
df_for_EDA_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6505 entries, 0 to 6504
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ownerNo                            6505 non-null   int64
#  1   oem                                6505 non-null   category
#  2   modelYear                          6505 non-null   int64
#  3   price_cleaned                      6505 non-null   float64
#  4   Car overview - Kms Driven          6505 non-null   int32
#  5   Car overview - Insurance Validity  6505 non-null   category
#  6   Car overview - Fuel Type           6505 non-null   category
#  7   Car overview - Transmission        6505 non-null   category
#  8   No of Features                     6505 non-null   int64
#  9   Mileage                            6505 non-null   float64
#  10  Engine(CC)                         6505 non-null   float64
# ...

# %%
df_for_EDA_updated = df_for_EDA_updated.drop('oem', 
    axis=1, 
    errors='ignore'
)
df_for_EDA_updated
# Out:
#       ownerNo  modelYear  price_cleaned  Car overview - Kms Driven  \
# 0           3       2015       400000.0                     120000
# 1           2       2018       811000.0                      32706
# 2           1       2018       585000.0                      11949
# 3           1       2014       462000.0                      17794
# 4           1       2015       790000.0                      60000
# ...       ...        ...            ...                        ...
# 6500        1       2009       150000.0                      30000
# 6501        1       2022       510000.0                      10000
# 6502        1       2014       180000.0                     120000
# 6503        1       2012       140000.0                      40000
# 6504        2       2017       500000.0                     120000
#
#      Car overview - Insurance Validity Car overview - Fuel Type  \
# 0                Third Party insurance                   Petrol
# ...
